# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Results_of_the_2009_Indian_general_election_by_parliamentary_constituency'

# %%
tables = pd.read_html(url)

tables
# Out:
# [                            0          1         2         3             4   \
#  0    ParliamentaryConstituency      St/UT  Congress       BJP  BahujanSamaj
#  1                     Adilabad         AP    257181     57931         16471
#  2                         Agra         UP     93373    203697        193982
#  3                   Ahmednagar         MH       NaN    312047         11508
#  4               Ahmedabad East         GJ    232790    318846          7254
#  5               Ahmedabad West         GJ    285696    376823          8436
#  6                        Ajmer         RJ    405575    329440          9180
#  7                     Akbarpur         UP    192549    136907        160506
#  8                        Akola         MH    182776    287526           NaN
#  9                    Alappuzha         KL    468679       NaN          4813
#  10                     Alathur         KL    366392     53890          3603
# ...

# %%
type(tables)
# Out:
# list

# %%
electionresults = tables[0]
electionresults

# new= electionresults.drop(electionresults.columns[[12, 13, 14, 15]], axis=1)
# new
# Out:
#                             0          1         2         3             4   \
# 0    ParliamentaryConstituency      St/UT  Congress       BJP  BahujanSamaj
# 1                     Adilabad         AP    257181     57931         16471
# 2                         Agra         UP     93373    203697        193982
# 3                   Ahmednagar         MH       NaN    312047         11508
# 4               Ahmedabad East         GJ    232790    318846          7254
# 5               Ahmedabad West         GJ    285696    376823          8436
# 6                        Ajmer         RJ    405575    329440          9180
# 7                     Akbarpur         UP    192549    136907        160506
# 8                        Akola         MH    182776    287526           NaN
# 9                    Alappuzha         KL    468679       NaN          4813
# 10                     Alathur         KL    366392     53890          3603
# ...
